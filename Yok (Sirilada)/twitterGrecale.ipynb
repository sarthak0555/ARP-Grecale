# %%
import pandas as pd
import os
from datetime import date, datetime
import sys
import base64
import requests
import re
import tweepy

# %%
api_key = "uUkzfQCzMuGCAPFouh16L0IHN"
api_key_secret = "VJCQcowCyFJHeYnMJTnBNrwHChAsS0DophCHpNgLCISrMLv0pI"
access_token = "948553306468597760-NcS2I66G7AQiq5MRsZIgFpqQgXuGnHs"
access_token_secret = "ldSqNVTmmSGNZDuWLuATKVmomH1DAIHo46LE7e9rqeXNW"

# Authorize twitter
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#dataframe to store the search
twitterdf = pd.DataFrame(columns=["Username", "Text","Followers", "Number of Retweets", "Number of Likes", "Location", "Date", "Tweet ID"])

# Keywords to search
keywords = "Grecale AND Maserati"

# %%
for tweet in tweepy.Cursor(api.search_tweets, q=keywords, lang="en", since="2020-09-10",tweet_mode='extended').items():
    username = tweet.user.screen_name
    text = tweet.full_text
    followers = tweet.user.followers_count
    retweets = tweet.retweet_count
    likes = tweet.favorite_count
    location = tweet.user.location
    date = tweet.created_at
    tweet_id = tweet.id  # getting tweet ID

    # Appending to the dataframe
    twitterdf = twitterdf.append({"Username": username, "Text": text, "Followers": followers, "Number of Retweets": retweets, "Number of Likes": likes, "Location": location, "Date": date, "Tweet ID": tweet_id}, ignore_index=True)
# Out:
# Unexpected parameter: since
# /var/folders/_5/xgykdqgs55749jx1z7t6gbjh0000gn/T/ipykernel_672/446103590.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   twitterdf = twitterdf.append({"Username": username, "Text": text, "Followers": followers, "Number of Retweets": retweets, "Number of Likes": likes, "Location": location, "Date": date, "Tweet ID": tweet_id}, ignore_index=True)
# /var/folders/_5/xgykdqgs55749jx1z7t6gbjh0000gn/T/ipykernel_672/446103590.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   twitterdf = twitterdf.append({"Username": username, "Text": text, "Followers": followers, "Number of Retweets": retweets, "Number of Likes": likes, "Location": location, "Date": date, "Tweet ID": tweet_id}, ignore_index=True)
# ...

# %%
twitterdf
# Out:
#            Username                                               Text  \
# 0      CharlyBoy007  RT @whatcar: As a sports SUV, the new Maserati...
# 1        motormetry  RT @AutoExpress: We hit the road in Maserati’s...
# 2         RobinMcA9  RT @autocar: REVIEW: The entry-level version o...
# 3     Bharat_jaimil  RT @whatcar: As a sports SUV, the new Maserati...
# 4           whatcar  As a sports SUV, the new Maserati Grecale has ...
# ..              ...                                                ...
# 117     HenrysLocks  #fb Maserati Grecale https://t.co/v19kA2jUV5 \...
# 118        ProXL_UK  New Maserati Grecale GT 2023 review https://t....
# 119   mosaccoblue77  RT @gearpatrol: We take Maserati's newest cros...
# 120      SC_Leasing  Maserati has revealed its first ever fully-ele...
# 121  shopsmartautos  2023 Maserati Grecale GT: Combining Power, Ele...
#
#     Followers Number of Retweets Number of Likes  \
# 0         578                  2               0
# ...
